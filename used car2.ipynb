# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
list1 = ["audi","bmw","cclass","focus","ford","hyundi","merc","skoda","toyota","vauxhall","vw"]

car_list=[] # empty list
  
# append datasets into the list
for i in range(len(list1)):  
    
    temp_df = pd.read_csv("./cars company/"+list1[i]+".csv") 
    car_list.append(temp_df)

# %%
car_list[5]# only it has tax value in pounds
# Out:
#         model  year  price transmission  mileage fuelType  tax(£)   mpg  \
# 0         I20  2017   7999       Manual    17307   Petrol     145  58.9
# 1      Tucson  2016  14499    Automatic    25233   Diesel     235  43.5
# 2      Tucson  2016  11399       Manual    37877   Diesel      30  61.7
# 3         I10  2016   6499       Manual    23789   Petrol      20  60.1
# 4        IX35  2015  10199       Manual    33177   Diesel     160  51.4
# ...       ...   ...    ...          ...      ...      ...     ...   ...
# 4855      I30  2016   8680       Manual    25906   Diesel       0  78.4
# 4856      I40  2015   7830       Manual    59508   Diesel      30  65.7
# 4857      I10  2017   6830       Manual    13810   Petrol      20  60.1
# 4858   Tucson  2018  13994       Manual    23313   Petrol     145  44.8
# 4859   Tucson  2016  15999    Automatic    11472   Diesel     125  57.6
#
#       engineSize
# 0            1.2
# 1            2.0
# 2            1.7
# 3            1.0
# ...

# %%
car_list[5]["tax"]=car_list[5]["tax(£)"] # to convert tax in pound to normal tax

# %%
car_list[5]
# Out:
#         model  year  price transmission  mileage fuelType   mpg  engineSize  \
# 0         I20  2017   7999       Manual    17307   Petrol  58.9         1.2
# 1      Tucson  2016  14499    Automatic    25233   Diesel  43.5         2.0
# 2      Tucson  2016  11399       Manual    37877   Diesel  61.7         1.7
# 3         I10  2016   6499       Manual    23789   Petrol  60.1         1.0
# 4        IX35  2015  10199       Manual    33177   Diesel  51.4         2.0
# ...       ...   ...    ...          ...      ...      ...   ...         ...
# 4855      I30  2016   8680       Manual    25906   Diesel  78.4         1.6
# 4856      I40  2015   7830       Manual    59508   Diesel  65.7         1.7
# 4857      I10  2017   6830       Manual    13810   Petrol  60.1         1.0
# 4858   Tucson  2018  13994       Manual    23313   Petrol  44.8         1.6
# 4859   Tucson  2016  15999    Automatic    11472   Diesel  57.6         1.7
#
#       tax  makers
# 0     145  hyundi
# ...

# %%
car_list[4]
# Out:
#          model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7
# 1        Focus  2018  14000       Manual     9083   Petrol  150  57.7
# 2        Focus  2017  13000       Manual    12456   Petrol  150  57.7
# 3       Fiesta  2019  17500       Manual    10460   Petrol  145  40.3
# 4       Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7
# ...        ...   ...    ...          ...      ...      ...  ...   ...
# 17960   Fiesta  2016   7999       Manual    31348   Petrol  125  54.3
# 17961    B-MAX  2017   8999       Manual    16700   Petrol  150  47.1
# 17962    B-MAX  2014   7499       Manual    40700   Petrol   30  57.7
# 17963    Focus  2015   9999       Manual     7010   Diesel   20  67.3
# 17964       KA  2018   8299       Manual     5007   Petrol  145  57.7
#
#        engineSize makers
# 0             1.0   ford
# 1             1.0   ford
# 2             1.0   ford
# ...

# %%
car_list[5].drop(["tax(£)"],axis=1,inplace=True) # dropping tax in pound

# %%
car_list[5] #  after dropping tax in pound
# Out:
#         model  year  price transmission  mileage fuelType   mpg  engineSize  \
# 0         I20  2017   7999       Manual    17307   Petrol  58.9         1.2
# 1      Tucson  2016  14499    Automatic    25233   Diesel  43.5         2.0
# 2      Tucson  2016  11399       Manual    37877   Diesel  61.7         1.7
# 3         I10  2016   6499       Manual    23789   Petrol  60.1         1.0
# 4        IX35  2015  10199       Manual    33177   Diesel  51.4         2.0
# ...       ...   ...    ...          ...      ...      ...   ...         ...
# 4855      I30  2016   8680       Manual    25906   Diesel  78.4         1.6
# 4856      I40  2015   7830       Manual    59508   Diesel  65.7         1.7
# 4857      I10  2017   6830       Manual    13810   Petrol  60.1         1.0
# 4858   Tucson  2018  13994       Manual    23313   Petrol  44.8         1.6
# 4859   Tucson  2016  15999    Automatic    11472   Diesel  57.6         1.7
#
#       tax
# 0     145
# 1     235
# 2      30
# ...

# %%
for i in range(len(list1)):
    car_list[i]["makers"]=list1[i]# to add makers column in list

# %%
car_list[0]
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        A1  2017  12500       Manual    15735   Petrol  150  55.4
# 1        A6  2016  16500    Automatic    36203   Diesel   20  64.2
# 2        A1  2016  11000       Manual    29946   Petrol   30  55.4
# 3        A4  2017  16800    Automatic    25952   Diesel  145  67.3
# 4        A3  2019  17300       Manual     1998   Petrol  145  49.6
# ...     ...   ...    ...          ...      ...      ...  ...   ...
# 10663    A3  2020  16999       Manual     4018   Petrol  145  49.6
# 10664    A3  2020  16999       Manual     1978   Petrol  150  49.6
# 10665    A3  2020  17199       Manual      609   Petrol  150  49.6
# 10666    Q3  2017  19499    Automatic     8646   Petrol  150  47.9
# 10667    Q3  2016  15999       Manual    11855   Petrol  150  47.9
#
#        engineSize makers
# 0             1.4   audi
# 1             2.0   audi
# 2             1.4   audi
# 3             2.0   audi
# 4             1.0   audi
# ...

# %%
df=pd.concat([car_list[0],car_list[1],car_list[2],car_list[3],car_list[4],car_list[5],car_list[6],car_list[7],car_list[8],car_list[9],car_list[10]])

# %%
df.head()
# Out:
#   model  year  price transmission  mileage fuelType    tax   mpg  engineSize  \
# 0    A1  2017  12500       Manual    15735   Petrol  150.0  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20.0  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30.0  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145.0  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145.0  49.6         1.0
#
#   makers
# 0   audi
# 1   audi
# 2   audi
# 3   audi
# 4   audi

# %%
df=df.reset_index() # to resetting index of data after concatinating
df.drop(["index"],axis=1,inplace=True)

# %%
df['year'] = 2020 - df['year']
df = df.rename(columns={"year":"age"})# For getting age of the car

# %%
df.shape # to see no.of rows and columns
# Out:
# (108540, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108540 entries, 0 to 108539
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   model         108540 non-null  object
#  1   age           108540 non-null  int64
#  2   price         108540 non-null  int64
#  3   transmission  108540 non-null  object
#  4   mileage       108540 non-null  int64
#  5   fuelType      108540 non-null  object
#  6   tax           99187 non-null   float64
#  7   mpg           99187 non-null   float64
#  8   engineSize    108540 non-null  float64
#  9   makers        108540 non-null  object
# dtypes: float64(3), int64(3), object(4)
# memory usage: 8.3+ MB

# %% [markdown]
# ### Replacing columns name

# %%
df.rename(columns={"mpg":"Mileage"},inplace=True)

# %%
df.rename(columns={"mileage":"distance"},inplace=True)

# %%
df.columns
# Out:
# Index(['model', 'age', 'price', 'transmission', 'distance', 'fuelType', 'tax',
#        'Mileage', 'engineSize', 'makers'],
#       dtype='object')

# %% [markdown]
# ## EDA -Exploratory Data Anlysis

# %% [markdown]
# Univariate Analysis is done see  distribution and patterns in the data

# %% [markdown]
# ### Distance

# %%
df["distance"].describe()
# Out:
# count    108540.000000
# mean      23025.928469
# std       21176.423684
# min           1.000000
# 25%        7491.750000
# 50%       17265.000000
# 75%       32236.000000
# max      323000.000000
# Name: distance, dtype: float64

# %%
q1, q3=np.percentile(df["distance"],[25,75]) # take 25 and 75 percentile of q1 and q3 resp.
print(q1,q3)

iqr_value=q3-q1 
print(iqr_value)

ubv=q3 +(1.5 * iqr_value) 


print(ubv)
# Out:
# 7491.75 32236.0
# 24744.25
# 69352.375

# %%
sns.displot(df["distance"])

# %% [markdown]
# 75 % of cars have travelled upto  32236 miles

# %%
sns.boxplot(df["distance"])
# Out:
# <AxesSubplot:xlabel='distance'>

# %% [markdown]
# ### Mileage

# %%
df["Mileage"].describe()
# Out:
# count    99187.000000
# mean        55.166825
# std         16.138522
# min          0.300000
# 25%         47.100000
# 50%         54.300000
# 75%         62.800000
# max        470.800000
# Name: Mileage, dtype: float64

# %%
q1= (np.nanpercentile(df["Mileage"], 25))
q3= (np.nanpercentile(df["Mileage"], 75))
print(q1,q3)
iqr=q3-q1
print(iqr)

ubv=q3 +(1.5 * iqr_value) 
lbv=q1 -(1.5 * iqr_value) 
print(lbv,ubv)
# Out:
# 47.1 62.8
# 15.699999999999996
# -37069.275 37179.175

# %%
sns.displot(df["Mileage"])

# %% [markdown]
# 75% of cars have have the milegae of 61 mpg

# %%
sns.boxplot(df["Mileage"])
# Out:
# <AxesSubplot:xlabel='Mileage'>

# %% [markdown]
# ### Age- Defines the age of car in years

# %%
df["age"].describe()
# Out:
# count    108540.000000
# mean          2.901972
# std           2.130057
# min         -40.000000
# 25%           1.000000
# 50%           3.000000
# 75%           4.000000
# max          50.000000
# Name: age, dtype: float64

# %%
df[df["age"]==-40]
# Out:
#          model  age  price transmission  distance fuelType    tax  Mileage  \
# 48528   Fiesta  -40   6495    Automatic     54807   Petrol  205.0     42.8
#
#        engineSize makers
# 48528         1.4   ford

# %%
df=df.drop([48528])

# %%
df[df["age"]==-40]
# Out:
# Empty DataFrame
# Columns: [model, age, price, transmission, distance, fuelType, tax, Mileage, engineSize, makers]
# Index: []

# %%
df["age"].describe()
# Out:
# count    108539.000000
# mean          2.902367
# std           2.126083
# min           0.000000
# 25%           1.000000
# 50%           3.000000
# 75%           4.000000
# max          50.000000
# Name: age, dtype: float64

# %%
q1, q3=np.percentile(df["age"],[25,75]) # take 25 anf 75 percentile of q1 and q3 resp.
print(q1,q3)

iqr_value=q3-q1 
print(iqr_value)

ubv=q3 +(1.5 * iqr_value) 

print(ubv)
# Out:
# 1.0 4.0
# 3.0
# 8.5

# %%
plt.hist(df["age"],bins=20)
plt.show()

# %% [markdown]
# 75 % cars have age 4 years

# %%
sns.boxplot(df["age"])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
df[df["age"]==50]
# Out:
#           model  age  price transmission  distance fuelType    tax  Mileage  \
# 65699   M Class   50  24999    Automatic     14000   Diesel  305.0     39.2
# 90588    Zafira   50  10495       Manual     37357   Petrol  200.0     42.2
#
#        engineSize    makers
# 65699         0.0      merc
# 90588         1.4  vauxhall

# %% [markdown]
# #### There are two cars whose age is  50

# %% [markdown]
# ### Tax

# %%
df["tax"].describe()
# Out:
# count    99186.000000
# mean       120.298984
# std         63.150672
# min          0.000000
# 25%        125.000000
# 50%        145.000000
# 75%        145.000000
# max        580.000000
# Name: tax, dtype: float64

# %%
q1, q3=np.nanpercentile(df["tax"],[25,75]) # take 25 and 75 percentile of q1 and q3 resp.
print(q1,q3)

iqr_value=q3-q1 # IQR_VALUE=Q3-Q1
print(iqr_value)

lbv=q1 -(1.5 * iqr_value) 
ubv=q3 +(1.5 * iqr_value) 

print(lbv,ubv)
# Out:
# 125.0 145.0
# 20.0
# 95.0 175.0

# %%
plt.hist(df["tax"],bins=10)
plt.show()

# %% [markdown]
# 75% of cars have tax of 145 imposed on them

# %%
sns.boxplot(df["tax"])
# Out:
# <AxesSubplot:xlabel='tax'>

# %% [markdown]
# ### EngineSize

# %%
df["engineSize"].describe()
# Out:
# count    108539.000000
# mean          1.661646
# std           0.557060
# min           0.000000
# 25%           1.200000
# 50%           1.600000
# 75%           2.000000
# max           6.600000
# Name: engineSize, dtype: float64

# %%
df[df["engineSize"]==0]
# Out:
#           model  age  price transmission  distance fuelType    tax  Mileage  \
# 7505         Q5    1  44790    Automatic      5886   Petrol  135.0    117.7
# 7506         Q3    1  32788    Automatic      1500   Diesel  145.0     47.1
# 7516         Q3    0  29944       Manual      1500   Petrol  145.0     40.9
# 7517         Q3    0  33333    Automatic      1500   Diesel  145.0     47.1
# 7518         Q3    0  29944    Automatic      1500   Petrol  145.0     32.5
# ...         ...  ...    ...          ...       ...      ...    ...      ...
# 105031   Tiguan    4  15300       Manual     38398   Diesel  145.0     53.3
# 105038   Tiguan    2  24000    Automatic     22200   Diesel  145.0     47.9
# 106204       Up    3   8500       Manual     20324   Petrol   20.0     64.2
# 106262       Up    3   8000       Manual     24444   Petrol   20.0     60.1
# 106695   Beetle    3  13800       Manual     17859   Petrol  125.0     53.3
#
#         engineSize makers
# 7505           0.0   audi
# ...

# %%
df["engineSize"].mode()[0]
# Out:
# 2.0

# %%
df.loc[df["engineSize"]==0,"engineSize"]=df["engineSize"].mode()[0]

# %%
df["engineSize"].describe()
# Out:
# count    108539.000000
# mean          1.666916
# std           0.550739
# min           0.600000
# 25%           1.200000
# 50%           1.600000
# 75%           2.000000
# max           6.600000
# Name: engineSize, dtype: float64

# %%
plt.hist(df["engineSize"],bins=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(df["engineSize"])
# Out:
# <AxesSubplot:xlabel='engineSize'>

# %% [markdown]
# #### There is imbalanced in the dataset ,75% of cars have enginesize betweeen 1 and 2

# %% [markdown]
# ### makers

# %%
df["makers"].value_counts()
# Out:
# ford        17964
# vw          15157
# vauxhall    13632
# merc        13119
# bmw         10781
# audi        10668
# toyota       6738
# skoda        6267
# focus        5454
# hyundi       4860
# cclass       3899
# Name: makers, dtype: int64

# %%
arr_df=df['makers'].value_counts()

# %%
plt.figure(figsize=(10,10))
cplot=sns.countplot(data=df, x='makers',order=arr_df.index)
for p in cplot.patches: 
    cplot.annotate((p.get_height()),
                   (p.get_x() , p.get_height()), 
                   xytext = (7, 5),  
                   textcoords = 'offset points')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Showing the makers distribution,ford produces the largest no.of cars (17964)

# %% [markdown]
# ### Transmission

# %%
df["transmission"].value_counts()
# Out:
# Manual       61308
# Semi-Auto    24903
# Automatic    22318
# Other           10
# Name: transmission, dtype: int64

# %%
arr_df2=df['transmission'].value_counts()

# %%
plt.figure(figsize=(8, 6))
cplot=sns.countplot(x="transmission",data=df,order=arr_df2.index)
for p in cplot.patches: 
    cplot.annotate((p.get_height()), 
                   (p.get_x(), p.get_height()), 
                   xytext = (20, 3),  
                   textcoords = 'offset points')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### showing the gear types of cars,61308 of the cars has manual transmission

# %% [markdown]
# ### fuelType

# %%
df["fuelType"].value_counts()
# Out:
# Petrol      59874
# Diesel      45177
# Hybrid       3229
# Other         253
# Electric        6
# Name: fuelType, dtype: int64

# %%
plt.figure(figsize=(8, 6))
cplot=sns.countplot(x="fuelType",data=df)
for p in cplot.patches: 
    cplot.annotate((p.get_height()),
                   (p.get_x(), p.get_height()),
                   xytext = (12, 3), 
                   textcoords = 'offset points')
    
    
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### showing fuelType distribution of cars,59874 runs runs on petrol engine

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# It is done between two variable to find relationship between two variables

# %% [markdown]
# ### Trsansmission and price

# %%
trans=df[["transmission","price"]].groupby("transmission").mean().sort_values(by="price",ascending=False)

# %%
trans
# Out:
#                      price
# transmission
# Semi-Auto     24296.493314
# Automatic     21488.757012
# Other         15796.700000
# Manual        12207.998141

# %%
trans=trans.reset_index()

# %%
trans
# Out:
#   transmission         price
# 0    Semi-Auto  24296.493314
# 1    Automatic  21488.757012
# 2        Other  15796.700000
# 3       Manual  12207.998141

# %%
plt.figure(figsize=(9, 7))
cplot=sns.barplot(x="transmission",y="price",data=trans)
for p in cplot.patches: 
    cplot.annotate(np.round(p.get_height(),2), 
                   (p.get_x(), p.get_height()), 
                   xytext = (20, 3),  
                   textcoords = 'offset points')
    
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# #### Transmission wise distribution of cars w.r.t to price , on an average semi automatic cars have the maximum  average price(24296.49)

# %% [markdown]
# ### fuelType and price

# %%
fuelp=df[["fuelType","price"]].groupby("fuelType").mean().sort_values(by="price",ascending=False)

# %%
fuelp
# Out:
#                  price
# fuelType
# Hybrid    19261.139362
# Diesel    19197.868207
# Other     17501.782609
# Electric  16645.333333
# Petrol    15018.596302

# %%
fuelp=fuelp.reset_index()

# %%
fuelp
# Out:
#    fuelType         price
# 0    Hybrid  19261.139362
# 1    Diesel  19197.868207
# 2     Other  17501.782609
# 3  Electric  16645.333333
# 4    Petrol  15018.596302

# %%
plt.figure(figsize=(9, 7))
cplot=sns.barplot(x="fuelType",y="price",data=fuelp)
for p in cplot.patches: 
    cplot.annotate(np.round(p.get_height(),2), 
                   (p.get_x(), p.get_height()),
                   xytext = (10, 3),
                   textcoords = 'offset points')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
#  #### Distribution of fueType w.r.t price, on an average cars runs on hybrid fuel has the maximum  price(19261.13)

# %% [markdown]
# ###  Compare makers with price

# %%
makers1=df[["makers","price"]].groupby("makers").mean().sort_values(by="price",ascending=False)

# %%
makers1
# Out:
#                  price
# makers
# merc      24698.596920
# cclass    23674.286997
# audi      22896.685039
# bmw       22733.408867
# vw        16838.952365
# skoda     14275.449338
# focus     13581.958379
# hyundi    12750.131070
# toyota    12522.391066
# ford      12280.078435
# vauxhall  10406.457893

# %%
makers1=makers1.reset_index()

# %%
makers1
# Out:
#       makers         price
# 0       merc  24698.596920
# 1     cclass  23674.286997
# 2       audi  22896.685039
# 3        bmw  22733.408867
# 4         vw  16838.952365
# 5      skoda  14275.449338
# 6      focus  13581.958379
# 7     hyundi  12750.131070
# 8     toyota  12522.391066
# 9       ford  12280.078435
# 10  vauxhall  10406.457893

# %%
plt.figure(figsize=(12, 10))
cplot=sns.barplot(x="makers",y="price",data=makers1)
for p in cplot.patches: 
    cplot.annotate(np.round(p.get_height(),2),
                   (p.get_x() , p.get_height()),
                   xytext = (1, 3),  
                   textcoords = 'offset points')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# #### On an average with respect to Price
#
# #### audi,bmw and merc has higher price becuase of luxirious collection
#
# #### whereas vw,hyundi and skoda  comes in averge
#
# ####  vauxhall,toyota and ford are comparitively chepaer

# %% [markdown]
# ### FuelType and Mileage

# %%
fuel1=df[["fuelType","Mileage"]].groupby("fuelType").mean().sort_values(by="Mileage",ascending=False)

# %%
fuel1
# Out:
#              Mileage
# fuelType
# Electric  297.066667
# Hybrid     89.052729
# Other      85.606883
# Diesel     58.226058
# Petrol     50.825303

# %%
fuel1=fuel1.reset_index()

# %%
fuel1
# Out:
#    fuelType     Mileage
# 0  Electric  297.066667
# 1    Hybrid   89.052729
# 2     Other   85.606883
# 3    Diesel   58.226058
# 4    Petrol   50.825303

# %%
plt.figure(figsize=(12, 10))
cplot=sns.barplot(x="fuelType",y="Mileage",data=fuel1)
for p in cplot.patches: 
    cplot.annotate(np.round(p.get_height(),2),
                   (p.get_x(), p.get_height()), 
                   xytext = (25, 5),  
                   textcoords = 'offset points')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# #### electric car gives the best mileage(297.07)

# %%
df.columns
# Out:
# Index(['model', 'age', 'price', 'transmission', 'distance', 'fuelType', 'tax',
#        'Mileage', 'engineSize', 'makers'],
#       dtype='object')

# %% [markdown]
# ### Mileage and Price

# %%
sns.scatterplot(x="Mileage",y="price",data=df)
# Out:
# <AxesSubplot:xlabel='Mileage', ylabel='price'>

# %% [markdown]
# #### As the price rises ,Mileage decreases  it could be because the person who can afford high priced car ,dont worry about Mileage

# %% [markdown]
# ### Age and Price

# %%
sns.scatterplot(x="age",y="price",data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='price'>

# %% [markdown]
# #### Age is inversely proportional to price

# %% [markdown]
# ### Distance and Price

# %%
sns.scatterplot(x="distance",y="price",data=df)
# Out:
# <AxesSubplot:xlabel='distance', ylabel='price'>

# %% [markdown]
# #### The less travelled cars has more price

# %% [markdown]
# ### Age and Mileage

# %%
sns.scatterplot(x="Mileage",y="age",data=df)
# Out:
# <AxesSubplot:xlabel='Mileage', ylabel='age'>

# %% [markdown]
# ####  Mileage of the car decreases with increase in age

# %% [markdown]
# ## Multivariate Analysis

# %%
sns.pairplot(df,height=5)

# %% [markdown]
# ###### This Is a Pairplot between all the variables.showing relationship between every variable,This plot is used to see the trend our our data

# %% [markdown]
# ### Insights From EDA /KPI'S

# %% [markdown]
# 1.Maker-ford has the maximum number of cars(17965),it could be because ford is the largest producer of cars
#
# 2.(61308) cars have manual transmission it could be because manual transmission cars have lower price
#
# 3.Semi automatic cars has the highest mean price(24296) ,it could be because these cars have both manual and autoimatic transmission
#
# 4.Hybrid   have the highest mean  price(19291), it could be beacuse it gives best performence and are  powered by an internal combustion engine and an electric motor, which uses energy stored in batteries whuch makes it costly
#
# 5.Mercedes makes most luxirious cars average price(24698) and vauxhall has  the cheapest average price(10406)
#
# 6.Electric cars has the highest Mileage(297.07)

# %% [markdown]
# ### Missing Values

# %%
df.isnull().sum()
# Out:
# model              0
# age                0
# price              0
# transmission       0
# distance           0
# fuelType           0
# tax             9353
# Mileage         9353
# engineSize         0
# makers             0
# dtype: int64

# %%
df.isnull().sum()/len(df)*100 # to see % of missing values
# Out:
# model           0.000000
# age             0.000000
# price           0.000000
# transmission    0.000000
# distance        0.000000
# fuelType        0.000000
# tax             8.617179
# Mileage         8.617179
# engineSize      0.000000
# makers          0.000000
# dtype: float64

# %% [markdown]
# ### Handling Missing Values

# %% [markdown]
# #### Missing values in Mileage

# %%
df["Mileage"].mean()
# Out:
# 55.16695017440294

# %%
df["Mileage"].median()
# Out:
# 54.3

# %%
df["Mileage"].skew()
# Out:
# 8.936513267597865

# %% [markdown]
# #### Since skewness of our data is more,we will replace it by median

# %%
df["Mileage"]=df["Mileage"].fillna(df["Mileage"].median())

# %% [markdown]
# ### Missing values in Tax

# %%
df["tax"].mean()
# Out:
# 120.2989837275422

# %%
df["tax"].median()
# Out:
# 145.0

# %%
df["tax"].skew()
# Out:
# 0.027166441611190816

# %% [markdown]
# #### Since skewness of our data is less,we will replace it by mean

# %%
df["tax"]=df["tax"].fillna(df["tax"].mean())

# %%
df.isnull().sum()/len(df)*100 # to see % of missing values
# Out:
# model           0.0
# age             0.0
# price           0.0
# transmission    0.0
# distance        0.0
# fuelType        0.0
# tax             0.0
# Mileage         0.0
# engineSize      0.0
# makers          0.0
# dtype: float64

# %% [markdown]
# ## Feature Encoding

# %% [markdown]
# ### Transmission

# %%
df["transmission"].value_counts()
# Out:
# Manual       61308
# Semi-Auto    24903
# Automatic    22318
# Other           10
# Name: transmission, dtype: int64

# %%
e={'Manual':1, 'Semi-Auto':2, 'Automatic':3,
'Other':4}

# %%
df["transmission"]=df["transmission"].map(e)

# %%
df["transmission"].value_counts()
# Out:
# 1    61308
# 2    24903
# 3    22318
# 4       10
# Name: transmission, dtype: int64

# %% [markdown]
# ### Fuel Type

# %%
df["fuelType"].value_counts()
# Out:
# Petrol      59874
# Diesel      45177
# Hybrid       3229
# Other         253
# Electric        6
# Name: fuelType, dtype: int64

# %%
f={'Petrol':1, 'Diesel':2, 'Hybrid':3,
'Other':4,'Electric':5}

# %%
df["fuelType"]=df["fuelType"].map(f)

# %%
df["fuelType"].value_counts()
# Out:
# 1    59874
# 2    45177
# 3     3229
# 4      253
# 5        6
# Name: fuelType, dtype: int64

# %% [markdown]
# ### Makers

# %%
df["makers"].value_counts()
# Out:
# ford        17964
# vw          15157
# vauxhall    13632
# merc        13119
# bmw         10781
# audi        10668
# toyota       6738
# skoda        6267
# focus        5454
# hyundi       4860
# cclass       3899
# Name: makers, dtype: int64

# %%
g={'ford':1, 'vw':2, 'vauxhall':3,
'merc':4,'bmw':5,'audi':6,'toyota':7,'skoda':8,'focus':9,'hyundi':10,'cclass':11}

# %%
df["makers"]=df["makers"].map(g)

# %%
df["makers"].value_counts()
# Out:
# 1     17964
# 2     15157
# 3     13632
# 4     13119
# 5     10781
# 6     10668
# 7      6738
# 8      6267
# 9      5454
# 10     4860
# 11     3899
# Name: makers, dtype: int64

# %% [markdown]
# ### Label Encoding

# %% [markdown]
# #### Model

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()

# %%
le.fit(df["model"])
# Out:
# LabelEncoder()

# %%
df['model']=le.transform(df["model"])

# %%
df["model"]
# Out:
# 0          9
# 1         14
# 2          9
# 3         12
# 4         11
#           ..
# 108535    57
# 108536    62
# 108537    62
# 108538    62
# 108539    62
# Name: model, Length: 108539, dtype: int32

# %%
df
# Out:
#         model  age  price  transmission  distance  fuelType    tax  Mileage  \
# 0           9    3  12500             1     15735         1  150.0     55.4
# 1          14    4  16500             3     36203         2   20.0     64.2
# 2           9    4  11000             1     29946         1   30.0     55.4
# 3          12    3  16800             3     25952         2  145.0     67.3
# 4          11    1  17300             1      1998         1  145.0     49.6
# ...       ...  ...    ...           ...       ...       ...    ...      ...
# 108535     57    8   5990             1     74000         2  125.0     58.9
# 108536     62   12   1799             1     88102         1  145.0     46.3
# 108537     62   11   1590             1     70000         1  200.0     42.0
# 108538     62   14   1250             1     82704         1  150.0     46.3
# 108539     62   13   2295             1     74000         1  145.0     46.3
#
#         engineSize  makers
# 0              1.4       6
# ...

# %% [markdown]
# ## Outliers

# %% [markdown]
# #### What is an Outlier?
#
# An outlier is a data point in data set that is distant from all other observations. A data point that lies outside the overall distribution of dataset.

# %% [markdown]
# # Handling outliers

# %% [markdown]
# ### Replacing Outliers with upper and lower bound value
#
# In this method on basis of IQR range we Replace outliers pounts with upper and lower bound value, the points that lies outside lower bound are replaced with lower bound value and the points while lie above upper bound are replaced with upper bound value

# %% [markdown]
# ### Mileage

# %%
sns.boxplot(df["Mileage"],color="red")
plt.title("boxplot before Replacing Outliers")
plt.show()

# %%
df["Mileage"].describe()
# Out:
# count    108539.000000
# mean         55.092244
# std          15.429461
# min           0.300000
# 25%          47.100000
# 50%          54.300000
# 75%          61.400000
# max         470.800000
# Name: Mileage, dtype: float64

# %%
df.drop(df[df["Mileage"]>=400].index,inplace=True)

# %%
plt.title("Boxplot after replacing outliers")
sns.boxplot(df["Mileage"],color="green")
# Out:
# <AxesSubplot:title={'center':'Boxplot after replacing outliers'}, xlabel='Mileage'>

# %% [markdown]
# ### Tax

# %%
sns.boxplot(df["tax"],color="red")
plt.title("boxplot before Replacing Outliers")
plt.show()

# %%
for i in df["tax"]:
    q1, q3=np.percentile(df["tax"],[25,75]) # take 25 and 75 percentile of q1 and q3 



    iqr_value=q3-q1 # iqr_value=q3-q1
   

    lbv=q1 -(1.5 * iqr_value) 
    ubv=q3 +(1.5 * iqr_value) 
    
    

    if i>ubv:
        df["tax"]= df["tax"].replace(i,ubv)
    if i<lbv:
        df["tax"]= df["tax"].replace(i,lbv)

# %%
plt.title("Boxplot after replacing outliers")
sns.boxplot(df["tax"],color="green")
# Out:
# <AxesSubplot:title={'center':'Boxplot after replacing outliers'}, xlabel='tax'>

# %% [markdown]
# ### Age

# %%
df.drop(df[df["age"]>=30].index,inplace=True)

# %%
sns.boxplot(df["age"],color="green")
# Out:
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# ### Correlation

# %% [markdown]
# Correlation is defined as the linear relationship between two variables ,how one variable depends on another variable
#
#
# correlation is of three types:
#
# 1.Positive correlation-in this type of correlation in which two variables move in same direction,if x increases ,y also increases
#
# 2.Negative correlation-in this type of correlation in which two variable moves in opposite direction,if x increases why decreases
#
# 3.zero correlation - when there is no relationship between the 2 variables

# %% [markdown]
# A perfect negative correlation is represented by the value -1.0,
#
#  0 indicates no correlation,
#
# +1.0 indicates a perfect positive correlation.

# %%
df.corr()
# Out:
#                  model       age     price  transmission  distance  fuelType  \
# model         1.000000 -0.027029  0.028445     -0.066746 -0.044433 -0.001797
# age          -0.027029  1.000000 -0.500568     -0.080659  0.748530  0.066033
# price         0.028445 -0.500568  1.000000      0.459426 -0.427971  0.199389
# transmission -0.066746 -0.080659  0.459426      1.000000 -0.055738  0.344000
# distance     -0.044433  0.748530 -0.427971     -0.055738  1.000000  0.201575
# fuelType     -0.001797  0.066033  0.199389      0.344000  0.201575  1.000000
# tax           0.108133 -0.188208  0.297678      0.172539 -0.210653 -0.145412
# Mileage      -0.173627  0.146608 -0.342369     -0.095691  0.205451  0.410685
# engineSize   -0.013070  0.046109  0.638860      0.464770  0.108648  0.446862
# makers       -0.049740 -0.029733  0.113754      0.185235 -0.011051  0.109163
#
#                    tax   Mileage  engineSize    makers
# model         0.108133 -0.173627   -0.013070 -0.049740
# ...

# %%
plt.figure(figsize=(8,8))

sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Observations:
#
#
# **Tax and engineSize are positively correlated to price.**
#
#
# Tax is directly proportional to price as various taxations are added to the price.
#
# Engine Size and proportional more powerful engines tend to have higher price.
#
#
# **Negative correlation is seen in age,distanceand Mileage w.r.t to price**
#
# Older the car gets it price decreases,price depriciates with age
#
# More the car travelled lesser will be its selling price

# %% [markdown]
# ## Applying Different Algoriths
#
# Since our Dependent variable is of Regression type ,we will apply Regression algortiths here.

# %% [markdown]
# 1.linear regression
#
# 2.desicion tree
#
# 3.random forest
#
# 4.Xg boost

# %%
df.columns
# Out:
# Index(['model', 'age', 'price', 'transmission', 'distance', 'fuelType', 'tax',
#        'Mileage', 'engineSize', 'makers'],
#       dtype='object')

# %% [markdown]
# # Linear Regression
#
# Linear Regression is used when the dependent variable(target) is continous in nature.

# %%
X=df[['age', 'transmission', 'distance', 'fuelType', 'tax',
       'engineSize', 'Mileage','model','makers']]

y=df["price"]

# %%
X
# Out:
#         age  transmission  distance  fuelType         tax  engineSize  \
# 0       3.0             1     15735         1  150.000000         1.4
# 1       4.0             3     36203         2   83.247459         2.0
# 2       4.0             1     29946         1   83.247459         1.4
# 3       3.0             3     25952         2  145.000000         2.0
# 4       1.0             1      1998         1  145.000000         1.0
# ...     ...           ...       ...       ...         ...         ...
# 108535  8.0             1     74000         2  125.000000         2.0
# 108536  8.5             1     88102         1  145.000000         1.2
# 108537  8.5             1     70000         1  182.051524         1.4
# 108538  8.5             1     82704         1  150.000000         1.2
# 108539  8.5             1     74000         1  145.000000         1.2
#
#         Mileage  model  makers
# 0          55.4      9       6
# 1          64.2     14       6
# ...

# %% [markdown]
# ##### Split the data into Training set and testing set using Train_Test_Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=101)

# %% [markdown]
# ### Importing and Fitting the Model

# %%
from sklearn.linear_model import LinearRegression # Importing linear regression model

# %%
lm=LinearRegression() # lm depicts the logmodel we are using

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Cofficients

# %% [markdown]
# ### The coefficients -Tells the dependency strenght
#  The size of the coefficient for each independent variable tell the dependency of that variable on dependent variable and sign gives the direction of effect.

# %%
print('Coefficients: \n', lm.coef_)
# Out:
# Coefficients:
#  [-2.05162917e+03  1.60389908e+03 -8.09436708e-02  3.87859540e+02
#  -3.91327648e+01  1.00568160e+04 -1.57118700e+02  1.25611085e+00
#  -6.02134563e+00]

# %% [markdown]
# ### Predictions and Evaluations

# %%
predictions=lm.predict(X_test)

# %%
df1 = pd.DataFrame({'Actual': y_test, 'Predicted': predictions})

# %%
df1
# Out:
#        Actual     Predicted
# 90722    5491   6293.583414
# 90914    4995    861.432849
# 84315    9900   6275.793214
# 7775    26444  20814.740756
# 16845   63999  40029.639227
# ...       ...           ...
# 96777   21450  21797.100722
# 25175   24944  27553.515959
# 54074   16498  22028.160775
# 82266    5995   4100.743241
# 76764    9990  13267.813058
#
# [32562 rows x 2 columns]

# %%
plt.scatter(y_test,predictions)# Here we draw scatter plot to see relation between actual and predicted values
plt.xlabel(' y_test')
plt.ylabel('pedictions')
# Out:
# Text(0, 0.5, 'pedictions')

# %%
from sklearn import metrics # These are different evaluation metrices

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 3321.409035020283
# MSE: 23953333.468754355
# RMSE: 4894.214285128345

# %%
coeffecients = pd.DataFrame(lm.coef_,X.columns) # variables with their cofficient
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
#                Coeffecient
# age           -2051.629169
# transmission   1603.899075
# distance         -0.080944
# fuelType        387.859540
# tax             -39.132765
# engineSize    10056.816013
# Mileage        -157.118700
# model             1.256111
# makers           -6.021346

# %% [markdown]
# ### Final Score

# %%
lm.score(X_test,y_test)*100
# Out:
# 75.22164682927158

# %% [markdown]
# it means 75% of the variation in the dependent variable is explained by  linear relationship with independent variables in X and leftover is from other factors
#
#
# if RSquare =0,it means there is no linear relationship dependent and independent variable
#
# if RSquare=1, means perfect linear relationship between dependent and independent variable
#
#
# The closer the value of RSquare to 1 the better is fit
#
# The closer the value of RSquare to 0 the poor is fit

# %% [markdown]
# # Decison Tree & Random Forest

# %% [markdown]
# #### Train the Model

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtree = DecisionTreeRegressor()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ### Prediction and Evaluation

# %%
predictions = dtree.predict(X_test)

# %%
print(predictions)
# Out:
# [ 5499.  3995.  9120. ... 18998.  5849.  9450.]

# %%
df2 = pd.DataFrame({'Actual': y_test, 'Predicted': predictions})

# %%
df2
# Out:
#        Actual  Predicted
# 90722    5491     5499.0
# 90914    4995     3995.0
# 84315    9900     9120.0
# 7775    26444    28062.0
# 16845   63999    64772.0
# ...       ...        ...
# 96777   21450    18000.0
# 25175   24944    24780.0
# 54074   16498    18998.0
# 82266    5995     5849.0
# 76764    9990     9450.0
#
# [32562 rows x 2 columns]

# %%
from sklearn import metrics # These are different evaluation metrices

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 1462.7229555050628
# MSE: 6863921.557461712
# RMSE: 2619.9086925810434

# %%
dtree.score(X_test,y_test)*100
# Out:
# 92.89966581441297

# %% [markdown]
# ##  Training the Random Forest model

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfc = RandomForestRegressor()

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ### Predictions and Evaluation

# %%
predictions = rfc.predict(X_test)

# %%
df3 = pd.DataFrame({'Actual': y_test, 'Predicted': predictions})

# %%
df3
# Out:
#        Actual     Predicted
# 90722    5491   5908.080000
# 90914    4995   4754.490000
# 84315    9900   9391.120000
# 7775    26444  26361.260000
# 16845   63999  65860.460000
# ...       ...           ...
# 96777   21450  18821.540000
# 25175   24944  24254.420000
# 54074   16498  20743.550000
# 82266    5995   5619.280000
# 76764    9990  10262.578333
#
# [32562 rows x 2 columns]

# %%
from sklearn import metrics # These are different evaluation metrices

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 1195.3742773825495
# MSE: 4757968.079777587
# RMSE: 2181.276708668019

# %%
rfc.score(X_test,y_test)*100
# Out:
# 95.07815421141413

# %% [markdown]
# # Xgboost

# %%
from xgboost import XGBRegressor

# %% [markdown]
# ### Fitting the Model

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=101)

# %%
xmodel=XGBRegressor()

# %%
xmodel.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %% [markdown]
# ### Prediction and Evaluations

# %%
predictions=xmodel.predict(X_test)

# %%
print(predictions)
# Out:
# [ 5960.1006  4840.9014  8964.992  ... 20607.818   5761.4644 10193.059 ]

# %%
df4= pd.DataFrame({'Actual': y_test, 'Predicted': predictions})

# %%
df4
# Out:
#        Actual     Predicted
# 90722    5491   5960.100586
# 90914    4995   4840.901367
# 84315    9900   8964.992188
# 7775    26444  23949.476562
# 16845   63999  64084.519531
# ...       ...           ...
# 96777   21450  19900.166016
# 25175   24944  25220.822266
# 54074   16498  20607.818359
# 82266    5995   5761.464355
# 76764    9990  10193.058594
#
# [32562 rows x 2 columns]

# %%
from sklearn import metrics # These are different evaluation metrices

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 1246.223690722983
# MSE: 4448896.817926955
# RMSE: 2109.240815536945

# %%
xmodel.score(X_test,y_test)*100
# Out:
# 95.3978707507028

# %% [markdown]
# ### Results

# %% [markdown]
# 1.Linear Regression - 75.02
#
# 2.Desicion Tree - 92.89
#
# 3.Random Forest- 95.02
#
# 4.XG Boost - 95.39
